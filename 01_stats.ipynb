# %% [markdown]
# # Basic statistics for the COVID19 IIPC collection.
#
# In this notebook we'll do some basic and descriptives statistics around the files we got from the COVID19 IIPC collection.
#
# It is based on and inpspired by the [original code from Nick Ruest and the Archive Unleashed team](https://github.com/archivesunleashed/notebooks).

# %% [markdown]
# # Datasets
#
# In this section, we don't download the data, as it is too big. The data we are using should have been download prior and stored, in *.gz* files in a directory called 'data' which is in the same folder as this notebook.

# %% [markdown]
# Unzip the data. We unzip them here, as there seem to be a bug in macOS when you use the Apple provided tools. If it's already unzipped, it will be skipped.

# %%
# !gunzip data/*
# Out:
# gunzip: data/audio-information.csv: unknown suffix -- ignored
# gunzip: data/domain-frequency.csv: unknown suffix -- ignored
# gunzip: data/domain-graph.csv: unknown suffix -- ignored
# gunzip: data/image-graph.csv: unknown suffix -- ignored
# gunzip: data/image-information.csv: unknown suffix -- ignored
# gunzip: data/pdf-information.csv: unknown suffix -- ignored
# gunzip: data/powerpoint-information.csv: unknown suffix -- ignored
# gunzip: data/spreadsheet-information.csv: unknown suffix -- ignored
# gunzip: data/video-information.csv: unknown suffix -- ignored
# gunzip: data/web-graph.csv: unknown suffix -- ignored
# gunzip: data/web-pages-en.csv: unknown suffix -- ignored
# gunzip: data/web-pages-fr.csv: unknown suffix -- ignored
# gunzip: data/web-pages.csv: unknown suffix -- ignored
# gunzip: data/word-document-information.csv: unknown suffix -- ignored

# %% [markdown]
# Let's check our `data` directory, and make sure they've downloaded.

# %%
# !ls -1 data
# Out:
# audio-information.csv
# domain-frequency.csv
# domain-graph.csv
# image-graph.csv
# image-information.csv
# pdf-information.csv
# powerpoint-information.csv
# spreadsheet-information.csv
# video-information.csv
# web-graph.csv
# web-pages-en.csv
# web-pages-fr.csv
# web-pages.csv
# word-document-information.csv

# %% [markdown]
# # Environment
#
# Next, we'll setup our environment so we can load our derivatives into [pandas](https://pandas.pydata.org).

# %%
import pandas as pd

# %% [markdown]
# # Loading our ARCH Datasets as DataFrames
#
# ---
#
#
#
# Next, we'll setup our datasets as pandas DataFrames to work with, and show a preview of each using the Data Table Display.
#
# Each block of derivative commands create a variable. That variable is a DataFrame with all of the information from a given derivative. After the DataFrame is created, a preview of it is shown.

# %% [markdown]
# ## Collection
#
# A basic overview of the collection.

# %% [markdown]
# ### Domain Frequency
#
# Provides the following columns:
#
# * domain
# * count

# %%
domain_frequency = pd.read_csv("data/domain-frequency.csv")
domain_frequency
# Out:
#                                 domain   count
# 0                          twitter.com  212409
# 1                         facebook.com  146781
# 2                          youtube.com   75608
# 3              coronavirus.rutgers.edu   70082
# 4                  accounts.google.com   68489
# ...                                ...     ...
# 161752               scripts.neemu.com       1
# 161753  salisburyhospicecharity.org.uk       1
# 161754                      gbgh.on.ca       1
# 161755                 gida-global.org       1
# 161756                   gadgetsin.com       1
#
# [161757 rows x 2 columns]

# %% [markdown]
# ## Network
# These derivative files provide network graph data for analysis, and offer an opportunity to explore the way websites link to each other.

# %% [markdown]
# ### Domain Graph
#
# Provides the following columns:
#
# * crawl date
# * source domain
# * target domain
# * count

# %%
domain_graph = pd.read_csv("data/domain-graph.csv")
domain_graph
# Out:
#          crawl_date                   source                      target  \
# 0          20200606              moph.gov.lb                 moph.gov.lb
# 1          20210201              moph.gov.lb                 moph.gov.lb
# 2          20201225       inumeraveis.com.br          inumeraveis.com.br
# 3          20200607              moph.gov.lb                 moph.gov.lb
# 4          20200224           ecdc.europa.eu              ecdc.europa.eu
# ...             ...                      ...                         ...
# 2283987    20200409  harfordcountyhealth.com                     npr.org
# 2283988    20200328          pressherald.com       homes.pressherald.com
# 2283989    20200408               clarin.com                facebook.com
# 2283990    20200314  newsroom.arlingtonva.us  departments.arlingtonva.us
# 2283991    20200221                nonio.net                  tvi.iol.pt
#
#            count
# 0        2180467
# 1        2140771
# 2        1880103
# 3        1876804
# 4        1839273
# ...          ...
# 2283987        6
# 2283988        6
# 2283989        6
# 2283990        6
# 2283991        6
#
# [2283992 rows x 4 columns]

# %% [markdown]
# ### Image Graph
#
# Provides the following columns:
#
# * crawl date
# * source of the image (where it was hosted)
# * the URL of the image
# * the alternative text of the image
#
# **Due to the size of the graph, this will take time.**

# %%
image_graph = pd.read_csv("data/image-graph.csv")
image_graph
# Out:
# /Users/frederic.clavert/opt/anaconda3/envs/awac2/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (0,1,2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          crawl_date                                             source  \
# 0          20200309  https://www.cdc.gov/coronavirus/2019-ncov/inde...
# 1          20200309  https://www.cdc.gov/coronavirus/2019-ncov/inde...
# 2          20200309  https://www.cdc.gov/coronavirus/2019-ncov/inde...
# 3          20200309  https://www.cdc.gov/coronavirus/2019-ncov/inde...
# 4          20200309  https://www.cdc.gov/coronavirus/2019-ncov/inde...
# ...             ...                                                ...
# 66789123   20200421  https://www.isciii.es/QueHacemos/Financiacion/...
# 66789124   20200421  https://www.isciii.es/QueHacemos/Financiacion/...
# 66789125   20200421  https://www.isciii.es/QueHacemos/Financiacion/...
# 66789126   20200421  https://www.isciii.es/QueHacemos/Financiacion/...
# 66789127   20200421  https://www.isciii.es/QueHacemos/Financiacion/...
#
#                                                         url  \
# 0         https://www.cdc.gov/coronavirus/2019-ncov/imag...
# 1         https://www.cdc.gov/coronavirus/2019-ncov/imag...
# 2         https://www.cdc.gov/coronavirus/2019-ncov/imag...
# 3         https://www.cdc.gov/coronavirus/2019-ncov/imag...
# 4         https://www.cdc.gov/coronavirus/2019-ncov/imag...
# ...                                                     ...
# 66789123  https://www.isciii.es/Style%20Library/ISCIII.P...
# 66789124  https://www.isciii.es/QueHacemos/Financiacion/...
# 66789125  https://www.isciii.es/_layouts/15/images/icpdf...
# 66789126  https://www.isciii.es/Style%20Library/ISCIII.P...
# 66789127  https://www.isciii.es/Style%20Library/ISCIII.P...
#
#                                                    alt_text
# 0                  3D illustration of the novel coronavirus
# 1                                    Woman holding a tissue
# 2         world map showing novel coronavirus cases per ...
# 3                      Jet airplane flying above the clouds
# 4                        3D Illustration of 2019-nCoV virus
# ...                                                     ...
# 66789123  Logo del gobierno de España - Instituto Carlos...
# 66789124                                         Logo FEDER
# 66789125                                                NaN
# 66789126                                           Imprimir
# 66789127                                                  *
#
# [66789128 rows x 4 columns]

# %% [markdown]
# ### Web Graph
#
# Provides the following columns:
#
# * crawl date
# * source
# * target
# * anchor text
#
# Note that this contains all links and is not aggregated into domains.
#
# **Due to the size of the graph, this will take time.**

# %%
web_graph = pd.read_csv("data/web-graph.csv")
web_graph
# Out:
#          crawl_date                                             source  \
# 0          20120119                            http://www.archive.org/
# 1          20120119                            http://www.archive.org/
# 2          20120119                            http://www.archive.org/
# 3          20120119                            http://www.archive.org/
# 4          20120119                            http://www.archive.org/
# ...             ...                                                ...
# 9596960    20120118  http://www.saigonnezumi.com/2009/10/14/work-pe...
# 9596961    20120118  http://www.saigonnezumi.com/2009/10/14/work-pe...
# 9596962    20120118  http://www.saigonnezumi.com/2009/10/14/work-pe...
# 9596963    20120118  http://www.saigonnezumi.com/2009/10/14/work-pe...
# 9596964    20120118  http://www.saigonnezumi.com/2009/10/14/work-pe...
#
#                                                     target    anchor_text
# 0                                  http://www.archive.org/            NaN
# 1                       http://www.archive.org/web/web.php            Web
# 2                    http://www.archive.org/details/movies  Moving Images
# 3                     http://www.archive.org/details/texts          Texts
# 4                     http://www.archive.org/details/audio          Audio
# ...                                                    ...            ...
# 9596960                               http://wordpress.org      WordPress
# 9596961                                   http://nginx.org          Nginx
# 9596962                             http://hakatagroup.com   Hakata Group
# 9596963                     http://americancensorship.org/            NaN
# 9596964  http://www.saigonnezumi.com/2009/10/14/work-pe...         Cancel
#
# [9596965 rows x 4 columns]

# %% [markdown]
# ## File Formats
#
# These derivatives contain information on certain types of binary files found within a web archive.

# %% [markdown]
# ### Audio
#
# Provides the following columns:
#
# * crawl date
# * URL of the audio file
# * filename
# * audio extension
# * MIME type as provided by the web server
# * MIME type as detected by Apache TIKA
# * audio MD5 hash
# * audio SHA1 hash

# %%
audio = pd.read_csv("data/audio-information.csv")
audio
# Out:
#        crawl_date                                                url  \
# 0        20200310  https://rstts-na.readspeaker.com/cgi-bin/nph-r...
# 1        20200310  https://www.cdc.gov/media/releases/2020/t0309-...
# 2        20200310  https://media.vaticannews.va/media/audio/progr...
# 3        20200309  https://accounts.google.com/Captcha?v=2&ctoken...
# 4        20200310  http://terrance.who.int/mediacentre/presser/WH...
# ...           ...                                                ...
# 12064    20200421  https://audio.hbr.org/after-hours/202004010901...
# 12065    20200421  https://covid19.govt.nz/assets/resources/audio...
# 12066    20200421  https://cpa.ds.npr.org/sdpb/audio/2020/03/0326...
# 12067    20200421  https://cpa.ds.npr.org/wdde/audio/2020/04/3496...
# 12068    20200421  https://cpa.ds.npr.org/wdde/audio/2020/04/3493...
#
#                                                 filename extension  \
# 0                   e98a11947968e8d931c1bb80fc46bc87.mp3       mp3
# 1                              t0309-covid-19-update.mp3       mp3
# 2                              inglese_africa_080320.mp3       mp3
# 3                                                Captcha       wav
# 4      WHO-AUDIO_Emergencies_Coronavirus_Press_Confer...       mp3
# ...                                                  ...       ...
# 12064  20200401090140-S3E25_TheVaryingInternationalRe...       mp3
# 12065                   COVID-19-Alert-Level-4-audio.mp3       mp3
# 12066                032620-elder_care_packages-wrap.mp3       mp3
# 12067                              34963_covidcheer1.mp3       mp3
# 12068                              34935_covidseals1.mp3       mp3
#
#       mime_type_web_server  mime_type_tika                               md5  \
# 0               audio/mpeg      audio/mpeg  6862c88c6112f27df27574588875f91f
# 1               audio/mpeg      audio/mpeg  615d2766ebfa29114d38d85d9f90d81b
# 2               audio/mpeg      audio/mpeg  4f6fcf7ffcd7622f3f4f433e09bc5b3a
# 3                audio/wav  audio/vnd.wave  2aaaeb51debef338c0cd2e057f47094a
# 4               audio/mpeg      audio/mpeg  681c8900a96f55e94823987959219fb9
# ...                    ...             ...                               ...
# 12064           audio/mpeg      audio/mpeg  938e1d4f9770ba0f6db9e6ef4f169f81
# 12065           audio/mpeg      audio/mpeg  4aeefecd7605c56d4df839e7732e4bca
# 12066           audio/mpeg      audio/mpeg  acb5331912c454eaf33a557ac4baacbd
# 12067           audio/mpeg      audio/mpeg  65c93ab69d6f72f5c64c2b0ee39a045e
# 12068           audio/mpeg      audio/mpeg  38be1f3182c25e9fda236b2103c89724
#
#                                            sha1
# 0      f7292ca899dad9e78036dcbaf8faab94f465b116
# 1      623bc9cf07c86f8ee3575408484c6515c316ddfb
# 2      bdb7f0d76d8c68cd34d61155bba92b4d60ce6386
# 3      6cb0146bf93ce8518c09988370104e62b85471fa
# 4      e9b9b377c1debac8cecf43be9143a11f47f81311
# ...                                         ...
# 12064  0bc3f3d1e0d8e88e4e511ce75149dc9d1b18acc9
# 12065  272ab3c429790ede1527feb98e5b044d8d5d3fab
# 12066  efdd2d59ce92b6e0039affe3cb11e42a7e80d74c
# 12067  2728df28ad2af37d0eddc15d829c8dc232b56d45
# 12068  cc31fbd92ff35faa011e42d1a4b86717c0504407
#
# [12069 rows x 8 columns]

# %% [markdown]
# ### Images
#
# Provides the following columns:
#
# * crawl date
# * URL of the image
# * filename
# * image extension
# * MIME type as provided by the web server
# * MIME type as detected by Apache TIKA
# * image width
# * image height
# * image MD5 hash
# * image SHA1 hash

# %%
images = pd.read_csv("data/image-information.csv")
images
# Out:
#          crawl_date                                                url  \
# 0          20200309  https://www.cdc.gov/coronavirus/2019-ncov/imag...
# 1          20200309  https://www.cdc.gov/coronavirus/2019-ncov/imag...
# 2          20200309  https://www.cdc.gov/coronavirus/2019-ncov/imag...
# 3          20200309  https://www.cdc.gov/coronavirus/2019-ncov/imag...
# 4          20200309  https://wwwnc.cdc.gov/travel/images/coronaviru...
# ...             ...                                                ...
# 4894994    20200421  https://www.isciii.es/SiteCollectionImages/Log...
# 4894995    20200421  https://www.isciii.es/SiteCollectionImages/Log...
# 4894996    20200421  https://www.isciii.es/SiteCollectionImages/Log...
# 4894997    20200421  https://www.isciii.es/SiteCollectionImages/Log...
# 4894998    20200421  https://www.isciii.es/SiteCollectionImages/Log...
#
#                                     filename extension mime_type_web_server  \
# 0                 home-situation-updates.jpg       jpg           image/jpeg
# 1                       covid-19-summary.png       png            image/png
# 2                       2019-coronavirus.png       jpg            image/png
# 3             outbreak-coronavirus-world.png       png            image/png
# 4                            coronavirus.jpg       jpg           image/jpeg
# ...                                      ...       ...                  ...
# 4894994                       logo_boe_1.jpg       jpg           image/jpeg
# 4894995               logo_union_europea.jpg       jpg           image/jpeg
# 4894996                      logo-cordis.jpg       jpg           image/jpeg
# 4894997      logo_hr_excellence_research.jpg       jpg           image/jpeg
# 4894998  logo_european_anti_fraud_office.jpg       jpg           image/jpeg
#
#         mime_type_tika  width  height                               md5  \
# 0           image/jpeg    381     189  fa2f77bf64b29c8267db598ac30c513b
# 1            image/png   1200     600  a3bd4b4b05e8f57a33e5a7f9a19db7f8
# 2           image/jpeg   1200     600  bda1a9566b4c3759bfd1defd7d5a938d
# 3            image/png   1501     738  3c6d6fcf87c40b5004db2b347779b169
# 4           image/jpeg    287     150  32a60f7d231155e3ccd8ffd6ee85853e
# ...                ...    ...     ...                               ...
# 4894994     image/jpeg    130      73  d2ee90b4a3067a6591351ddc707ef461
# 4894995     image/jpeg     90      95  ab4ee94755f232678f91343b4c8044d4
# 4894996     image/jpeg    330     200  9bb1bda033a1e12ae3658a3917cea2ac
# 4894997     image/jpeg    200     139  067adf7ba51d1459a1a3aea7ce21e010
# 4894998     image/jpeg    250      91  72eb907005f79afd218ac4279fec5315
#
#                                              sha1
# 0        3cbc410d55292bb95676118e156265578d01cda5
# 1        e4dde1d86f4b546bfe626aadf2ee47c22b99d763
# 2        e2d2e95c8c8c1bdba7ac763158e1a6c39bb53af0
# 3        b07d0d2cdac103077191296a3ced16ed2a8923de
# 4        a87d73c3686b2f3230f34c229007af3ddfc0c358
# ...                                           ...
# 4894994  452719990f504b875fb89e7017c5569ad31c0c33
# 4894995  430558c9c163c2704e1f57b4d6d14330c9a32aa5
# 4894996  7cd3b199b24a9553577e844b21fa99a2153bf001
# 4894997  85add10fa200c5eea46c391b311abf439dc019c3
# 4894998  b516131a159d497477af581a09070188afb0d741
#
# [4894999 rows x 10 columns]

# %% [markdown]
# ### PDFs
#
# Provides the following columns:
#
# * crawl date
# * URL of the PDF file
# * filename
# * PDF extension
# * MIME type as provided by the web server
# * MIME type as detected by Apache TIKA
# * PDF MD5 hash
# * PDF SHA1 hash

# %%
pdf = pd.read_csv("data/pdf-information.csv")
pdf
# Out:
#         crawl_date                                                url  \
# 0         20200228  https://the-eye.eu/CoronaVirusPapers/pdfs/2020...
# 1         20200228  https://the-eye.eu/CoronaVirusPapers/pdfs/2020...
# 2         20200228  https://the-eye.eu/CoronaVirusPapers/pdfs/2020...
# 3         20200228  https://the-eye.eu/CoronaVirusPapers/pdfs/2020...
# 4         20200309  https://www.cdc.gov/coronavirus/2019-ncov/down...
# ...            ...                                                ...
# 337575    20200421  https://judiciary.house.gov/uploadedfiles/2020...
# 337576    20200421  https://judiciary.house.gov/uploadedfiles/2020...
# 337577    20200421  https://www.health.govt.nz/system/files/docume...
# 337578    20200421  http://www.naiopma.org/uploads/7/4/6/6/7466587...
# 337579    20200421  https://www.empoweringsmallbusiness.org/sites/...
#
#                                                  filename extension  \
# 0       2020%20The%20continuing%202019-nCoV%20epidemic...       pdf
# 1       2020%20The%20continuing%202019-nCoV%20epidemic...       pdf
# 2       2020%20Preparedness%20and%20proactive%20infect...       pdf
# 3       2020%20Preparedness%20and%20proactive%20infect...       pdf
# 4                            guidance-law-enforcement.pdf       pdf
# ...                                                   ...       ...
# 337575  2020-04-07_nadler-lofgren_letter_to_albence_re...       pdf
# 337576           2020-03-13_letter_to_ice_re_covid-19.pdf       pdf
# 337577       covid-19-ppe-for-disabled-people-11apr20.pdf       pdf
# 337578  biz-equity-covid19-emergency-fund_overview-for...       pdf
# 337579  COVID-19%20Small%20Business%20Stabilization%20...       pdf
#
#        mime_type_web_server   mime_type_tika  \
# 0           application/pdf  application/pdf
# 1           application/pdf  application/pdf
# 2           application/pdf  application/pdf
# 3           application/pdf  application/pdf
# 4           application/pdf  application/pdf
# ...                     ...              ...
# 337575      application/pdf  application/pdf
# 337576      application/pdf  application/pdf
# 337577      application/pdf  application/pdf
# 337578      application/pdf  application/pdf
# 337579      application/pdf  application/pdf
#
#                                      md5  \
# 0       85414733f666465ca213706248e9ad9b
# 1       85414733f666465ca213706248e9ad9b
# 2       d73c30886b0411c50e97bade8127cea6
# 3       d73c30886b0411c50e97bade8127cea6
# 4       bbc8068810b52274f32c3664aa895540
# ...                                  ...
# 337575  3188c169fba04d541f1dcb30eafda71b
# 337576  d0c400dfc10ba9b840b7b3861018fcb8
# 337577  67c5256732adbbfcecf54c76983484ce
# 337578  bd1a399534a482dd6678ac9abd465ae9
# 337579  7f842b875c29a41874c9301c2be96821
#
#                                             sha1
# 0       13c100d15e19f010e71033a7174f1ba117f99bca
# 1       13c100d15e19f010e71033a7174f1ba117f99bca
# 2       99efef2203468fc25f3032281cd895d8f24294b4
# 3       99efef2203468fc25f3032281cd895d8f24294b4
# 4       cba9775d3b7816ff2339cac44783976aeccce01c
# ...                                          ...
# 337575  48d0cf97b2d967b34e419472671f50b900a7ef94
# 337576  d350da699eedae18d113d757c10f66c5773c24de
# 337577  334305fe30761fb1e1d3e403ab405568efad4263
# 337578  48e3e1ec143c7f53865262f6f520de8c65024d3f
# 337579  08a022b34de3ba89280304b1ee51f275d04d310a
#
# [337580 rows x 8 columns]

# %% [markdown]
# ### PowerPoint (all software types) information
#
# Provides the following columns:
#
# * crawl date
# * URL of a PowerPoint or similar file
# * filename
# * PowerPoint or similar file extension
# * MIME type as provided by the web server
# * MIME type as detected by Apache TIKA
# * PowerPoint or similar file MD5 hash
# * PowerPoint or similar file SHA1 hash

# %%
powerpoint = pd.read_csv("data/powerpoint-information.csv")
powerpoint
# Out:
#    crawl_date                                                url  \
# 0    20200422  https://www.cdc.gov.tw/File/Get/m7XIr1R9kJ5G8J...
# 1    20200422  https://www.cdc.gov.tw/File/Get/6r531G4DBi4ahJ...
# 2    20200422  https://www.cdc.gov.tw/File/Get/PlOm9SXt0D5I28...
# 3    20200424  https://www.cdc.gov.tw/En/File/Get/sqrAKrJg_Uq...
# 4    20200424  https://www.cdc.gov.tw/File/Get/mPecMSLOpsdehm...
#
#                  filename extension      mime_type_web_server  \
# 0  m7XIr1R9kJ5G8J6OJHofAQ       odp  application/octet-stream
# 1  6r531G4DBi4ahJb_qLbXKw       odp  application/octet-stream
# 2  PlOm9SXt0D5I28u5ltG0Aw       odp  application/octet-stream
# 3  sqrAKrJg_Uq8Ki5B0HtO3g       odp  application/octet-stream
# 4  mPecMSLOpsdehmfdh9Acsw       odp  application/octet-stream
#
#                                     mime_type_tika  \
# 0  application/vnd.oasis.opendocument.presentation
# 1  application/vnd.oasis.opendocument.presentation
# 2  application/vnd.oasis.opendocument.presentation
# 3  application/vnd.oasis.opendocument.presentation
# 4  application/vnd.oasis.opendocument.presentation
#
#                                 md5                                      sha1
# 0  2b00ce20793c2b1e7c6a39ab1efcc134  3aba45fe9ed66713265d709fef1f06a8c9ede158
# 1  feb9f4a261033acafd9eb8e7c7f0e44b  440dfbdfc08da2ef370cf610d3e3fa9e4379449a
# 2  d66e028d6ee817a6aee7fab166b689a5  2b3942e1652c94fddda0bc5a3aa2d2700ff0713a
# 3  45ad6488a6928122e9c5d984c68ade49  94d37168acdd5f69b0cafc5a4951ee4b36beebd7
# 4  27c6e6a577e78a3986eb7f04fc935d1d  cb6b88098037c33774d95e4a79362a7d9d822c29

# %% [markdown]
# ### Spreadsheets
#
# Provides the following columns:
#
# * crawl date
# * URL of the spreadsheet file
# * filename
# * spreadsheet extension
# * MIME type as provided by the web server
# * MIME type as detected by Apache TIKA
# * spreadsheet MD5 hash
# * spreadsheet SHA1 hash

# %%
spreadsheet = pd.read_csv("data/spreadsheet-information.csv")
spreadsheet
# Out:
#       crawl_date                                                url  \
# 0       20200323  https://static01.nyt.com/newsgraphics/2020/03/...
# 1       20200323  https://static01.nyt.com/newsgraphics/2020/03/...
# 2       20200325       https://covid19.isciii.es/resources/ccaa.csv
# 3       20200325       https://covid19.isciii.es/resources/data.csv
# 4       20200328  https://data.buzzfeed.com/projects/2020-02-cov...
# ...          ...                                                ...
# 7061    20200421  https://www.coronavirus.gov.hk/files/public_se...
# 7062    20200421  https://www.coronavirus.gov.hk/files/anti-epid...
# 7063    20200420       https://covid19.isciii.es/resources/ccaa.csv
# 7064    20200420       https://covid19.isciii.es/resources/data.csv
# 7065    20200420  https://covid19.isciii.es/resources/serie_hist...
#
#                             filename extension         mime_type_web_server  \
# 0                       usa-data.csv       txt  text/comma-separated-values
# 1                  regional-data.csv       txt  text/comma-separated-values
# 2                           ccaa.csv       txt     application/octet-stream
# 3                           data.csv       txt     application/octet-stream
# 4          cases_country_current.csv       txt                     text/csv
# ...                              ...       ...                          ...
# 7061             public_services.csv       txt                     text/csv
# 7062          anti-epidemic-fund.csv       txt                     text/csv
# 7063                        ccaa.csv       txt     application/octet-stream
# 7064                        data.csv       txt     application/octet-stream
# 7065  serie_historica_acumulados.csv       txt     application/octet-stream
#
#      mime_type_tika                               md5  \
# 0        text/plain  f76b44ae12303ac4da5744d30304b08a
# 1        text/plain  7b7c07aa25bf7f03b605063d0ae37e6e
# 2        text/plain  c250a8907b70484143a8bcdc60be4677
# 3        text/plain  e8864bb23301309807cd5963edab9cfd
# 4        text/plain  5ed04034f799083f17c6b3484c6c957e
# ...             ...                               ...
# 7061     text/plain  19aec131a932fd10617296e952a3f06a
# 7062     text/plain  fc7a5da2746b83d568ca790e3dd8e9b9
# 7063     text/plain  3539aba1a1fd87c6b922797b6f7433a9
# 7064     text/plain  e28a9b8672040485213065d20ac25a69
# 7065     text/plain  87a2a91262e3446e2df5ccbfd2e47c69
#
#                                           sha1
# 0     0bd6292e72c448c037b394ac94d38f4c6d4b7dd4
# 1     bc33dea473d4210e9c70a7702e2947e23afc0f29
# 2     9566e94699befaa5faec6360ddfd4e2bdf59a15b
# 3     9c2cf9b8a219a309589103eb021eafdbc0619831
# 4     ec0d20986c41efc9c9051b07c7a66a46c7bfe123
# ...                                        ...
# 7061  0363ec4b6d4d29cae51e8a7a93757a6940efe712
# 7062  25978b9ddec813f521a022612ab16fa715a51519
# 7063  1f27e5975f19b22325130a487c5f7b9b41598ec3
# 7064  35dd6823d180a34d2fe2b852d14bdf992e2899db
# 7065  0b2be4bf2d1d61e28677b5276ec2fc0394877d28
#
# [7066 rows x 8 columns]

# %% [markdown]
# ### Videos
#
# Provides the following columns:
#
# * crawl date
# * URL of the video file
# * filename
# * video extension
# * MIME type as provided by the web server
# * MIME type as detected by Apache TIKA
# * video MD5 hash
# * video SHA1 hash

# %%
video = pd.read_csv("data/video-information.csv")
video
# Out:
#        crawl_date                                                url  \
# 0        20200309  https://r4---sn-a5mekner.googlevideo.com/video...
# 1        20200310  https://r3---sn-n4v7sney.googlevideo.com/video...
# 2        20200310  https://r4---sn-n4v7sne7.googlevideo.com/video...
# 3        20200310  https://vdist.aws.mashable.com/cms/2020/3/eabe...
# 4        20200310  https://vdist.aws.mashable.com/cms/2020/3/eabe...
# ...           ...                                                ...
# 64566    20200421  https://r2---sn-n4v7knlk.googlevideo.com/video...
# 64567    20200421  https://r6---sn-n4v7sn7l.googlevideo.com/video...
# 64568    20200421  https://r3---sn-n4v7sne7.googlevideo.com/video...
# 64569    20200421  https://r4---sn-n4v7sn7z.googlevideo.com/video...
# 64570    20200420      https://covid19.isciii.es/resources/Video.mp4
#
#             filename extension mime_type_web_server   mime_type_tika  \
# 0      videoplayback       mp4            video/mp4        video/mp4
# 1      videoplayback       mp4            video/mp4        video/mp4
# 2      videoplayback       mp4            video/mp4        video/mp4
# 3           1080.mp4        qt            video/mp4  video/quicktime
# 4            720.mp4        qt            video/mp4  video/quicktime
# ...              ...       ...                  ...              ...
# 64566  videoplayback       mp4            video/mp4        video/mp4
# 64567  videoplayback       mp4            video/mp4        video/mp4
# 64568  videoplayback       mp4            video/mp4        video/mp4
# 64569  videoplayback       mp4            video/mp4        video/mp4
# 64570      Video.mp4       mp4            video/mp4        video/mp4
#
#                                     md5  \
# 0      f8f5e8781229a2c7d9dbd4399583f169
# 1      3c02af7137d40515c4a282f9378a77b1
# 2      c31900d26190dc8aa7d55084be90e5b0
# 3      f54e7a1a4bf3d33363c9dcdd7de8160e
# 4      e1b9a06bd299a93375d588c0ff47e6ac
# ...                                 ...
# 64566  87cdc6aac3d332d39241efc7f4bd958a
# 64567  4d3cb20aa77b9d48e96fb0f4468cd862
# 64568  e79d7baf895a9fdd0f2747137eb4cb09
# 64569  f0d156b2ee9caf59a3035a8b5483ecc8
# 64570  16b38c0477bc9cb0335b5ed821b7a553
#
#                                            sha1
# 0      36d0a70fb54acd92a2bd26166b04ef96126f574c
# 1      da53a01f793955c07d9f43092119b6d72747755a
# 2      cf3aaf0a14fda0a4422f255bdc472f2c33075a06
# 3      6d6056471c4fb549af8e53e5baee5a2fe129e37f
# 4      b4af84e12a711c704f73e226b8f4ea09750f1823
# ...                                         ...
# 64566  9bf4a826257172b0d9d7a209e1cb9d0ad8c83f51
# 64567  0a9525183a2956d5e92c23c895e9963ebdaf7c58
# 64568  859631ff408a6c8de5b0e8d77d12b82d1f608182
# 64569  7baad57fe4ecc1636e63a698a6fbcc13d529ca6b
# 64570  27c8771083c8f6d2cc814bfb51622ddea738afc6
#
# [64571 rows x 8 columns]

# %% [markdown]
# ### Word Documents (all software types)
#
# Provides the following columns:
#
# * crawl date
# * URL of the word document or similar file
# * filename
# * word document or similar file extension
# * MIME type as provided by the web server
# * MIME type as detected by Apache TIKA
# * word document or similar file MD5 hash
# * word document or similar file SHA1 hash

# %%
word = pd.read_csv("data/word-document-information.csv")
word
# Out:
#      crawl_date                                                url  \
# 0      20200330              https://www.mingtiandi.com/robots.txt
# 1      20200405  https://static.data.gouv.fr/resources/donnees-...
# 2      20200406  https://static.data.gouv.fr/resources/donnees-...
# 3      20200406  https://www.impots.gouv.fr/portail/files/media...
# 4      20200403  https://www.impots.gouv.fr/portail/files/media...
# ..          ...                                                ...
# 134    20200321  http://www.padovanet.it/sites/default/files/at...
# 135    20200324  https://www.nepia.com/lorient-questionnaire-co...
# 136    20200511  https://www.health.gov.sk/Zdroje?/Sources/doku...
# 137    20200511  https://www.health.gov.sk/Zdroje?/Sources/doku...
# 138    20200324  https://assets.publishing.service.gov.uk/gover...
#
#                                               filename extension  \
# 0                                           robots.txt       rtf
# 1                                 metadonnees-sexe.csv       rtf
# 2                                 metadonnees-sexe.csv       rtf
# 3    20200402_formulaire_fiscal_simplifie_delai_ou_...       odt
# 4    formulaire_fiscal_simplifie_delai_ou_remise_co...       odt
# ..                                                 ...       ...
# 134  2_Nuova_autocertificazione_spostamenti_Coronav...       rtf
# 135                                                NaN       odt
# 136                                             Zdroje       rtf
# 137                                             Zdroje       rtf
# 138         ENG_informal_translation_of_SoE_decree.odt       odt
#
#                         mime_type_web_server  \
# 0                                 text/plain
# 1                                   text/csv
# 2                                   text/csv
# 3    application/vnd.oasis.opendocument.text
# 4    application/vnd.oasis.opendocument.text
# ..                                       ...
# 134                          application/rtf
# 135                 application/octet-stream
# 136                            text/richtext
# 137                            text/richtext
# 138  application/vnd.oasis.opendocument.text
#
#                               mime_type_tika  \
# 0                            application/rtf
# 1                            application/rtf
# 2                            application/rtf
# 3    application/vnd.oasis.opendocument.text
# 4    application/vnd.oasis.opendocument.text
# ..                                       ...
# 134                          application/rtf
# 135  application/vnd.oasis.opendocument.text
# 136                          application/rtf
# 137                          application/rtf
# 138  application/vnd.oasis.opendocument.text
#
#                                   md5  \
# 0    49165e4010a10a9df8f2206f31366cf1
# 1    0e8d620b259c5fc33b88c0694cfd1b4d
# 2    0e8d620b259c5fc33b88c0694cfd1b4d
# 3    b2817bebac3d48edfe3bce6f5f1afddf
# 4    5881490f6a2d2f2bdc7819026bce6a38
# ..                                ...
# 134  a04578e7f7bb7f15ae7773f028e9033a
# 135  0328946256912fecb31f20b77ab2f0be
# 136  23ef844f5c0015b7163a28d432202516
# 137  23ef844f5c0015b7163a28d432202516
# 138  8d0c26b43e962bb40acec0d1672d4807
#
#                                          sha1
# 0    e63de16cf1c5b0e47f971dabc20af85156a7dae5
# 1    a8ce869dd07b486f3e40cff6b59d68365180871f
# 2    a8ce869dd07b486f3e40cff6b59d68365180871f
# 3    8d9231b4d00a1ff92939b40994b29e26bfeceaab
# 4    397be5001ad4b817e41194ee7381a1adcffc43ad
# ..                                        ...
# 134  eb56a904a2c7584d3ffb7ebbae7d056972f08cce
# 135  42ffc1d3a5b2529d604e29612a287196af9568e9
# 136  63f1c96f369aa1cb588a7ea72ddf403a43bb6f22
# 137  63f1c96f369aa1cb588a7ea72ddf403a43bb6f22
# 138  7139866e34f2ceb31b00a400dcf537b454b7c416
#
# [139 rows x 8 columns]

# %% [markdown]
# ## Text
#
# This derivative provides access to the "plain text" of a collection, extracted from web page HTML.

# %% [markdown]
# ### Web Pages
#
# Provides the following columns:
#
# * crawl date
# * web domain
# * URL
# * MIME type as provided by the web server
# * MIME type as detected by Apache TIKA
# * content (HTTP headers and HTML removed)
#
# **This file is HUGE! Here, limited to the first 1000 non-header rows**

# %%
web_pages = pd.read_csv("data/web-pages-FR.csv")
web_pages
# Out:
#         crawl_date                domain  \
# 0         20200309  googletagmanager.com
# 1         20200310               oie.int
# 2         20200310               fao.org
# 3         20200310  googletagmanager.com
# 4         20200310      merckmanuals.com
# ...            ...                   ...
# 254347    20200421            pasteur.fr
# 254348    20200421                cps.ca
# 254349    20200421         go.pardot.com
# 254350    20200421           inspq.qc.ca
# 254351    20200421              cibc.com
#
#                                                       url  \
# 0       https://www.googletagmanager.com/ns.html?id=GT...
# 1       https://www.oie.int/fr/expertise-scientifique/...
# 2                        http://www.fao.org/2019-ncov/fr/
# 3       https://www.googletagmanager.com/ns.html?id=GT...
# 4       https://www.merckmanuals.com/fr-ca/accueil/new...
# ...                                                   ...
# 254347  https://www.pasteur.fr/fr/nous-soutenir/covid-...
# 254348             https://www.cps.ca/fr/search-recherche
# 254349     https://go.pardot.com/l/375732/2017-07-24/275x
# 254350  https://www.inspq.qc.ca/publications/2906-pci-...
# 254351  https://www.cibc.com/fr/business/covid-19/emer...
#
#        mime_type_web_server         mime_type_tika language  \
# 0                 text/html              text/html       fr
# 1                 text/html  application/xhtml+xml       fr
# 2                 text/html  application/xhtml+xml       fr
# 3                 text/html              text/html       fr
# 4                 text/html              text/html       fr
# ...                     ...                    ...      ...
# 254347            text/html              text/html       fr
# 254348            text/html              text/html       fr
# 254349            text/html              text/html       fr
# 254350            text/html              text/html       fr
# 254351            text/html              text/html       fr
#
#                                                   content
# 0                                                      ns
# 1       Questions et réponses sur le COVID-19: OIE - W...
# 2       Nouveau coronavirus (2019-nCoV) | FAO | Organi...
# 3                                                      ns
# 4       Épidémie due à un nouveau coronavirus chez l’h...
# ...                                                   ...
# 254347  Covid-19 : comment soutenir les recherches de ...
# 254348  Résultats de la recherche | Société canadienne...
# 254349                                     Email Comments
# 254350  COVID-19 : Mesures de prévention et de contrôl...
# 254351  Compte d’urgence pour les entreprises canadien...
#
# [254352 rows x 7 columns]

# %%
web_pages.count()
# Out:
# crawl_date              254352
# domain                  254352
# url                     254352
# mime_type_web_server    254352
# mime_type_tika          254352
# language                254352
# content                 254352
# dtype: int64

# %%
len(web_pages.index)
# Out:
# 254352

# %% [markdown]
# Pivot-table to know how many times a domain has been crawl by date

# %%
groupby_web_pages = web_pages.groupby(by=['domain','crawl_date'], as_index=False).agg({'crawl_date': pd.Series.nunique})
groupby_web_pages
# Out:
#                  domain  crawl_date
# 0             01net.com           1
# 1             01net.com           1
# 2             01net.com           1
# 3             01net.com           1
# 4      104histoires.com           1
# ...                 ...         ...
# 27565          zulma.fr           1
# 27566         zurich.ch           1
# 27567         zurich.ch           1
# 27568         zurich.ch           1
# 27569         zurnal.rs           1
#
# [27570 rows x 2 columns]

# %% [markdown]
# # Data Analysis
#
# Now that we have all of our datasets loaded up, we can begin to work with them!

# %% [markdown]
# ## Counting total files, and unique files
#
# Let's take a quick look at how to count items in DataFrames, and use total and unique files as an example to work with.
#
# It's definitely work checking out the [pandas documentation](https://pandas.pydata.org/docs/index.html). There are a lot of good examples available, along with a robust [API reference](https://pandas.pydata.org/docs/reference/index.html#api).

# %% [markdown]
# #### How many images are in this collection?
#
# We can take our `images` variable try a couple of functions to get the same answer.
#
# 1.   `len(images.index)`
#   * Get the length of the DataFrame's index.
# 2.   `images.shape[0]`
#   * Get the shape or dimensionality of the DataFrame, and take the first item in the tuple.
# 3.  `images.count()`
#   * Count the number of rows for each column.

# %%
len(images.index)
# Out:
# 4894999

# %%
images.shape[0]
# Out:
# 4894999

# %%
images.count()
# Out:
# crawl_date              4894999
# url                     4894999
# filename                4846789
# extension               4894999
# mime_type_web_server    4894650
# mime_type_tika          4894999
# width                   4894999
# height                  4894999
# md5                     4894999
# sha1                    4894999
# dtype: int64

# %% [markdown]
#  #### How many unique images are in the collection?
#
#  We can see if an image is unique or not by computing an [MD5 hash](https://en.wikipedia.org/wiki/MD5#MD5_hashes) of it, and comparing them. The exact same image might have a filename of `example.jpg` or `foo.jpg`. If the hash is computed for each, we can see that even with different file names, they are actually the same image. So, since we have both a `MD5` and `SHA1` hash column available in our DataFrame, we can just find the unique values, and count them!

# %%
len(images.md5.unique())
# Out:
# 3336410

# %% [markdown]
# #### What are the top 10 most occurring images in the collection?
#
# Here we can take advantage of [`value_counts()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html) to provide us with a list of MD5 hashes, and their respective counts.

# %%
images["md5"].value_counts().head(10)
# Out:
# d89746888da2d9510b64a9f031eaecd5    6282
# ad4b0f606e0f8465bc4c4c170b37e1a3    6095
# b798f4ce7359fd815df4bdf76503b295    4164
# 325472601571f31e1bf00674c368d335    3566
# df3e567d6f16d040326c7a0ea29a4f41    2697
# 9bb191c6827273aa978cab39a3587950    2661
# 71a50dbba44c78128b221b7df7bb51f1    2190
# 221d8352905f2c38b3cb2bd191d630b0    2148
# 28d6814f309ea289f847c69cf91194c6    2061
# 377d257f2d2e294916143c069141c1c5    1867
# Name: md5, dtype: int64

# %% [markdown]
# #### What's the information around all of the occurances of `d89746888da2d9510b64a9f031eaecd5`?
#
# What, you mean you don't know what `d89746888da2d9510b64a9f031eaecd5` means?
#
# Let's find those images in the DataFrame. We can here see some of the filenames used, it's dimensions, and it's URL.

# %%
images.loc[images["md5"] == "d89746888da2d9510b64a9f031eaecd5"]
# Out:
#          crawl_date                                                url  \
# 14875      20200314  https://www.google.com/pagead/1p-user-list/100...
# 17136      20200323  https://pagead2.googlesyndication.com/pcs/acti...
# 26704      20200326  https://d9hhrg4mnvzow.cloudfront.net/participa...
# 26988      20200325  https://www.google.com/pagead/1p-user-list/931...
# 29907      20200325  https://dpm.demdex.net/demconf.jpg?et:ibs%7cda...
# ...             ...                                                ...
# 4791673    20200317  https://track.lexico.com/main.gif?ab=0&cb=9958...
# 4794751    20200324  https://pubads.g.doubleclick.net/gampad/ad?iu=...
# 4810229    20200324  https://pagead2.googlesyndication.com/pcs/acti...
# 4834995    20200330  https://s0.wp.com/wp-content/themes/vip/plugin...
# 4890983    20200421  https://ttm-validate.onecount.net/onecount/oc_...
#
#                  filename extension mime_type_web_server mime_type_tika  \
# 14875                 NaN       gif            image/gif      image/gif
# 17136          activeview       gif            image/gif      image/gif
# 26704     transparent.gif       gif            image/gif      image/gif
# 26988                 NaN       gif            image/gif      image/gif
# 29907         demconf.jpg       gif            image/gif      image/gif
# ...                   ...       ...                  ...            ...
# 4791673          main.gif       gif            image/gif      image/gif
# 4794751                ad       gif            image/gif      image/gif
# 4810229        activeview       gif            image/gif      image/gif
# 4834995     1x1.trans.gif       gif            image/gif      image/gif
# 4890983  tracker_nojs.php       gif            image/gif      image/gif
#
#          width  height                               md5  \
# 14875        1       1  d89746888da2d9510b64a9f031eaecd5
# 17136        1       1  d89746888da2d9510b64a9f031eaecd5
# 26704        1       1  d89746888da2d9510b64a9f031eaecd5
# 26988        1       1  d89746888da2d9510b64a9f031eaecd5
# 29907        1       1  d89746888da2d9510b64a9f031eaecd5
# ...        ...     ...                               ...
# 4791673      1       1  d89746888da2d9510b64a9f031eaecd5
# 4794751      1       1  d89746888da2d9510b64a9f031eaecd5
# 4810229      1       1  d89746888da2d9510b64a9f031eaecd5
# 4834995      1       1  d89746888da2d9510b64a9f031eaecd5
# 4890983      1       1  d89746888da2d9510b64a9f031eaecd5
#
#                                              sha1
# 14875    d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# 17136    d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# 26704    d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# 26988    d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# 29907    d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# ...                                           ...
# 4791673  d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# 4794751  d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# 4810229  d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# 4834995  d5fceb6532643d0d84ffe09c40c481ecdf59e15a
# 4890983  d5fceb6532643d0d84ffe09c40c481ecdf59e15a
#
# [6282 rows x 10 columns]

# %% [markdown]
# ### What does `377d257f2d2e294916143c069141c1c5` look like?
#
# Let's grab the live web URL for the image, and then see if we can display it in a markdown cell.

# %%
pd.options.display.max_colwidth = None
one_image = images.loc[images["md5"] == "377d257f2d2e294916143c069141c1c5"].head(1)
one_image["url"]
# Out:
# 367    https://analytics.twitter.com/i/adsct?txn_id=l4o6d&p_id=Twitter
# Name: url, dtype: object

# %% [markdown]
# ![377d257f2d2e294916143c069141c1c5](https://analytics.twitter.com/i/adsct?txn_id=l4o6d&p_id=Twitter)

# %% [markdown]
# Well, yes, this is a transparent GIF.

# %% [markdown]
# Another point of examination with the `images` DataFrame is the `height` and `width` columns. You could take a look at the largest images, or even `0x0` images, and potentially `spacer.gif` occurrences!
#
# * “[The invention and dissemination of the spacer gif: implications for the future of access and use of web archives](https://link.springer.com/article/10.1007/s42803-019-00006-8)”
# * "[GeoCities and the spacer.gif](https://ruebot.net/post/geocities-and-the-spacer-gif/)"

# %% [markdown]
# #### What are the top 10 most occuring filenames in the collection?
#
# Note that this is of course different than the MD5 results up above. Here we are focusing _just_ on filename. So `cover.jpg` for example, might actually be referring to different images who happen to have the same name.
#
# Here we can use `value_counts()` again, but this time we'll create a variable for the top filenames so we can use it later.

# %%
top_filenames = images["filename"].value_counts().head(10)
top_filenames
# Out:
# favicon.ico             149368
# hqdefault.jpg            46029
# favicon-32x32.png        20945
# favicon-16x16.png        18998
# apple-touch-icon.png     18782
# logo.png                 13411
# Document                 12877
# mw-320                   11396
# favicon.png              11044
# image.jpg                10937
# Name: filename, dtype: int64

# %% [markdown]
# #### Let's create our first graph!
#
# We'll plot the data first with pandas [plot](https://pandas.pydata.org/docs/reference/api/pandas.Series.plot.html) functionality, and then plot the data with [Altair](https://altair-viz.github.io/).

# %%
top_filenames_chart = top_filenames.plot.bar(figsize=(25, 10))

top_filenames_chart.set_title("Top Filenames", fontsize=22)
top_filenames_chart.set_xlabel("Filename", fontsize=20)
top_filenames_chart.set_ylabel("Count", fontsize=20)

# %% [markdown]
# Now let's setup Altair, and plot the data with Altair. Altair is useful for creating vizualization since they can be easily exported as a PNG or SVG.

# %%
import altair as alt

# %%
top_filenames_altair = (
    images["filename"]
    .value_counts()
    .head(10)
    .rename_axis("Filename")
    .reset_index(name="Count")
)

filenames_bar = (
    alt.Chart(top_filenames_altair)
    .mark_bar()
    .encode(x=alt.X("Filename:O", sort="-y"), y=alt.Y("Count:Q"))
)

filenames_rule = (
    alt.Chart(top_filenames_altair).mark_rule(color="red").encode(y="mean(Count):Q")
)


filenames_text = filenames_bar.mark_text(align="center", baseline="bottom").encode(
    text="Count:Q"
)

(filenames_bar + filenames_rule + filenames_text).properties(
    width=1400, height=700, title="Top Filenames"
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### How about a file format distribution?
#
# What _kind_ of image files are present? We can discover this by checking their "media type", or [MIME type](https://en.wikipedia.org/wiki/Media_type).

# %%
image_mime_types = (
    images["mime_type_tika"]
    .value_counts()
    .head(5)
    .rename_axis("MIME Type")
    .reset_index(name="Count")
)

image_mimes_bar = (
    alt.Chart(image_mime_types)
    .mark_bar()
    .encode(x=alt.X("MIME Type:O", sort="-y"), y=alt.Y("Count:Q"))
)

image_mime_rule = (
    alt.Chart(image_mime_types).mark_rule(color="red").encode(y="mean(Count):Q")
)

image_mime_text = image_mimes_bar.mark_text(align="center", baseline="bottom").encode(
    text="Count:Q"
)

(image_mimes_bar + image_mime_rule + image_mime_text).properties(
    width=1400, height=700, title="Image File Format Distribution"
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Let's take a look at the domain frequency derivative.

# %% [markdown]
# #### What does the distribution of domains look like?
#
# Here we can see which domains are the most frequent within the collection.

# %%
top_domains = domain_frequency.sort_values("count", ascending=False).head(10)

top_domains_bar = (
    alt.Chart(top_domains)
    .mark_bar()
    .encode(
        x=alt.X("domain:O", title="Domain", sort="-y"),
        y=alt.Y("count:Q", title="Count, Mean of Count"),
    )
)

top_domains_rule = (
    alt.Chart(top_domains).mark_rule(color="red").encode(y="mean(count):Q")
)

top_domains_text = top_domains_bar.mark_text(align="center", baseline="bottom").encode(
    text="count:Q"
)

(top_domains_bar + top_domains_rule + top_domains_text).properties(
    width=1400, height=700, title="Domains Distribution"
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Top Level Domain Analysis
#
# pandas allows you to create new columns in a DataFrame based off of existing data. This comes in handy for a number of use cases with the available data that we have. In this case, let's create a new column, `tld`, which is based off an existing column, 'domain'. This example should provide you with an implementation pattern for expanding on these datasets to do further research and analysis.
#
# A [top-level domain](https://en.wikipedia.org/wiki/Top-level_domain) refers to the highest domain in an address - i.e. `.ca`, `.com`, `.org`, or yes, even `.pizza`.
#
# Things get a bit complicated, however, in some national TLDs. While `qc.ca` (the domain for Quebec) isn't really a top-level domain, it has many of the features of one as people can directly register under it. Below, we'll use the command `suffix` to include this.
#
# > You can learn more about suffixes at https://publicsuffix.org.
#
# We'll take the `domain` column and extract the `tld` from it with [`tldextract`](https://github.com/john-kurkowski/tldextract).
#
# First we'll add the [`tldextract`](https://github.com/john-kurkowski/tldextract) library to the notebook. Then, we'll create the new column.

# %%
# %%capture

# !pip install tldextract

# %%
import tldextract

domain_frequency["tld"] = domain_frequency.apply(
    lambda row: tldextract.extract(row.domain).suffix, axis=1
)
domain_frequency
# Out:
#                                 domain   count     tld
# 0                          twitter.com  212409     com
# 1                         facebook.com  146781     com
# 2                          youtube.com   75608     com
# 3              coronavirus.rutgers.edu   70082     edu
# 4                  accounts.google.com   68489     com
# ...                                ...     ...     ...
# 161752               scripts.neemu.com       1     com
# 161753  salisburyhospicecharity.org.uk       1  org.uk
# 161754                      gbgh.on.ca       1   on.ca
# 161755                 gida-global.org       1     org
# 161756                   gadgetsin.com       1     com
#
# [161757 rows x 3 columns]

# %% [markdown]
# #### Next, let's count the distict TLDs.

# %%
tld_count = domain_frequency["tld"].value_counts()
tld_count
# Out:
# com                   75179
# org                   17942
# de                     5264
# net                    4577
# edu                    4302
#                       ...
# org.ai                    1
# gov.pn                    1
# physio                    1
# geometre-expert.fr        1
# lo.it                     1
# Name: tld, Length: 1195, dtype: int64

# %% [markdown]
# #### Next, we'll plot the TLD count.

# %%
tld_count = (
    domain_frequency["tld"]
    .value_counts()
    .rename_axis("TLD")
    .reset_index(name="Count")
    .head(10)
)

tld_bar = (
    alt.Chart(tld_count)
    .mark_bar()
    .encode(x=alt.X("TLD:O", sort="-y"), y=alt.Y("Count:Q"))
)

tld_rule = alt.Chart(tld_count).mark_rule(color="red").encode(y="mean(Count):Q")

tld_text = tld_bar.mark_text(align="center", baseline="bottom").encode(text="Count:Q")

(tld_bar + tld_rule + tld_text).properties(
    width=1400, height=700, title="Top Level Domain Distribution"
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Web Crawl Frequency
#
# Let's see what the crawl frequency looks like by examining the `web_pages` DataFrame. First we'll create a new DataFrame by extracting the `crawl_date` and `domain` columns, and count the occurances of each domain and date combination.

# %%
crawl_sites = web_pages[["crawl_date", "domain"]]
crawl_sites = crawl_sites.value_counts().reset_index()
crawl_sites.columns = ["Date", "Site", "Count"]
crawl_sites
# Out:
#            Date                      Site  Count
# 0      20210310          appel-a-prier.ch   5926
# 1      20210309          appel-a-prier.ch   5709
# 2      20210306                kariyon.ch   4873
# 3      20210309                kariyon.ch   3224
# 4      20200614             covid19hdf.fr   3210
# ...         ...                       ...    ...
# 27565  20200404     fr.firstdraftnews.org      1
# 27566  20200223  abo-investir.lesechos.fr      1
# 27567  20200404         fr.m.wikinews.org      1
# 27568  20200404        fr.m.wikiquote.org      1
# 27569  20200221       20minutes-media.com      1
#
# [27570 rows x 3 columns]

# %% [markdown]
# Next, we'll create a stacked bar chart where each bar will show the distribution of pages in that crawl by top-level domain.
#
# **NOTE**: Charts like this one work a lot better with collections that have more than 1 or 2 crawl dates. The temporal aspect is definitely something to take into consideration with each of the examples provided in this notebook.

# %%
## Altair has a default limit of 5000 rows, and this DataFrame is ~7700 rows, so we're going to disable the max allowed rows.
alt.data_transformers.disable_max_rows()

crawl_chart = (
    alt.Chart(crawl_sites)
    .mark_bar()
    .encode(
        x="Date:O",
        y="Count:Q",
        color="Site",
        tooltip="Site",
        order=alt.Order("Site", sort="descending"),
    )
)

crawl_chart.properties(width=1400, height=700, title="Web Crawl Frequency")
# Out:
# alt.Chart(...)
